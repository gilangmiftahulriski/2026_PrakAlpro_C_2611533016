# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“PENGENALAN PYTHON, VS CODE, DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Gilang Miftahul Riski**
#
# **2611533016**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Nama Asisten**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="image/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum “Pengenalan Python, VS Code, dan Koneksi ke GitHub” dengan baik. Laporan ini disusun sebagai dokumentasi dan refleksi atas praktikum yang telah dilaksanakan pada pertemuan minggu ke-1 untuk mata kuliah Praktikum Algoritma Pemrograman. Praktikum ini berfokus pada pengenalan bahasa pemrograman Python, penggunaan Visual Studio Code (VS Code) sebagai code editor, serta pengenalan koneksi dan pengelolaan kode program menggunakan GitHub.
#
# Melalui praktikum ini, output yang diharapkan adalah penulis dapat memahami konsep-konsep dasar pemrograman Python serta penggunaan VS Code dalam membuat dan menjalankan program. Dalam praktikum ini, penulis juga mempelajari cara menghubungkan proyek dengan GitHub untuk menyimpan, mengelola, dan membagikan kode program secara daring. Dengan adanya praktikum ini, penulis diharapkan dapat menerapkan pengetahuan yang diperoleh dalam pembuatan proyek-proyek sederhana serta memahami dasar penggunaan GitHub dalam proses pengembangan program.
#
# Padang, 2026
#
#
#
# Gilang Miftahul Riski
#
# 2611533016

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemrograman merupakan salah satu kemampuan penting dalam bidang Informatika. Sebagai mahasiswa Informatika semester 1, pemahaman dasar pemrograman perlu dikuasai untuk menunjang pembelajaran selanjutnya. Salah satu bahasa pemrograman yang banyak digunakan adalah Python karena memiliki sintaks yang sederhana dan mudah dipahami.
#
# Dalam proses pemrograman, diperlukan aplikasi untuk menulis dan menjalankan kode, salah satunya adalah Visual Studio Code (VS Code). Selain itu, GitHub dapat digunakan untuk menyimpan dan mengelola kode program secara daring. Oleh karena itu, praktikum Pengenalan Python, VS Code, dan Koneksi ke GitHub dilakukan untuk memberikan pemahaman dasar mengenai penggunaan Python, VS Code, serta GitHub dalam proses pengembangan program.
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar bahasa pemrograman Python.
# 2. Mampu menggunakan Visual Studio Code (VS Code) untuk menulis dan menjalankan program Python
# 3. Mampu menghubungkan proyek dari VS Code ke GitHub.
# 4. Memahami penggunaan GitHub untuk menyimpan dan mengelola kode program.
# 5. Mampu menerapkan Python, VS Code, dan GitHub dalam proyek sederhana.
#
# ## 1.3 Manfaat
# 1. Memberikan pengalaman kepada mahasiswa dalam membuat dan menjalankan program Python.
# 2. Meningkatkan kemampuan dalam menggunakan VS Code sebagai code editor.
# 3. Memberikan pemahaman mengenai penggunaan GitHub untuk mengelola kode program.
# 4. Membantu mahasiswa mengelola proyek pemrograman secara lebih terstruktur.
# 5. Menjadi dasar untuk mengembangkan kemampuan pemrograman pada proyek selanjutnya.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Praktikum Pengenalan Python, VS Code, dan Koneksi ke GitHub membahas dasar penggunaan bahasa pemrograman Python, Visual Studio Code sebagai code editor, serta GitHub sebagai media penyimpanan dan pengelolaan kode program.
#
# 1. Python
#
# Python merupakan bahasa pemrograman tingkat tinggi yang memiliki sintaks sederhana sehingga mudah dipahami oleh pemula. Python dapat digunakan untuk berbagai kebutuhan, seperti pembuatan aplikasi, pengolahan data, dan pengembangan perangkat lunak.
#
# 2. Visual Studio Code
#
# Visual Studio Code (VS Code) merupakan code editor yang digunakan untuk menulis, mengedit, dan menjalankan kode program. VS Code mendukung berbagai bahasa pemrograman, termasuk Python, serta menyediakan fitur seperti terminal, debugging, dan integrasi dengan Git.
#
# 3. Git
#
# Git merupakan sistem version control yang digunakan untuk mencatat perubahan pada kode program. Dengan Git, programmer dapat mengelola berbagai versi program dan mengetahui perubahan yang telah dilakukan.
#
# 4. GitHub
#
# GitHub merupakan platform berbasis daring yang digunakan untuk menyimpan dan mengelola repository Git. GitHub dapat membantu programmer dalam melakukan pencadangan kode, mengakses proyek dari berbagai perangkat, serta bekerja sama dalam pengembangan program.
#
# 5. Repository
#
#
# Repository merupakan tempat penyimpanan proyek yang berisi kode program dan berbagai berkas pendukung. Repository dapat disimpan secara lokal pada komputer maupun secara daring pada GitHub.
#
# 6. Commit dan Push
#
# Commit digunakan untuk menyimpan perubahan yang telah dilakukan pada repository lokal. Push digunakan untuk mengirim perubahan dari repository lokal ke repository yang berada di GitHub.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program B_2611533016
# Program Python dibuat menggunakan Visual Studio Code. Pada praktikum ini, Python digunakan untuk membuat dan menjalankan program sederhana sebagai pengenalan terhadap sintaks dasar bahasa Python.

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Departemen Informatika")
print("Universitas Andalas") 
print("/ \\ // \\\ /// \\\\\\")
print("program ini" + " dibuat oleh a\\n "
+ "Gilang Mifttahul Riski dan 2611533016. ")

# %% [markdown]
# ```python
# Hello World
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# program ini dibuat oleh a\n Gilang Mifttahul Riski dan 2611533016.
# ```

# %% [markdown]
# Penjelasan :
# 1. '#' digunakan sebagai simbol untuk command dalam bahasa python.
# 2. """ dogunakan untuk menyimpan string yang lebih dari satu baris code.
# 3. print() digunakan untuk menampilkan data ke layar.
# 4. Program dapat dijalankan melalui terminal atau fitur Run pada VS Code.

# %% [markdown]
# ### 2.2.2  Membuat Repository GitHub

# %% [markdown]
# Setelah program dibuat dan diuji pada VS Code, proyek dapat dihubungkan dengan GitHub. Repository digunakan untuk menyimpan kode program secara daring.
#
# Tahapan yang dilakukan yaitu:
#
# 1. Buat repositori baru di situs web GitHub.
# 2. Buka folder kerja proyek menggunakan aplikasi Visual Studio Code.
# 3. Akses terminal terintegrasi pada VS Code.
# 4. Jalankan perintah inisialisasi Git pada folder tersebut.
# 5. Masukkan seluruh berkas proyek ke dalam area staging.
# 6. Simpan perubahan dengan membuat pesan commit.
# 7. Hubungkan direktori lokal ke repositori remote di GitHub.
# 8. Unggah (push) seluruh berkas proyek ke repositori GitHub.
#
# Contoh perintah yang digunakan:

# %%
git init
git add .
git commit -m "Initial commit"
git branch -M main
git remote add origin https://github.com/username/nama-repository.git
git push -u origin main

# %% [markdown]
# Penjelasan:
# 1. ⁠git init⁠ untuk mulai mengaktifkan Git di folder proyek kita.
# 2. ⁠git add .⁠ untuk menyeleksi atau mengumpulkan semua file proyek supaya siap disimpan.
# 3. ⁠git commit -m "Initial commit"⁠ untuk menyimpan perubahan file ke catatan riwayat Git beserta catatannya.
# 4. ⁠git branch -M main⁠ untuk menamai cabang utama proyek kita menjadi ⁠main⁠.
# 5. ⁠git remote add origin untuk menyambungkan folder di komputer kita dengan repositori yang ada di web GitHub.
# 6. ⁠git push -u origin main⁠ untuk mengunggah/mengirim semua file dari komputer ke web GitHub.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="image/soal_praktikum.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program tugas1__2611533016

# %%
nama = input("Masukkan Nama : ")
tugas = int(input("Masukkan Nilai Tugas : "))
uts = int(input("Masukkan Nilai UTS : "))
uas = int(input("Masukkan Nilai UAS : "))

nilai_akhir = (tugas * 30 + uts * 30 + uas * 40) / 100

if nilai_akhir >= 85:
    predikat = "A"
elif nilai_akhir >= 70:
    predi = "B"
elif nilai_akhir >= 60:
    predikat = "C"
elif nilai_akhir >= 50:
    predikat = "D"
else:
    predikat = "E"

print("====== HASIL NILAI ======")
print("Nama           : ", nama)
print("Nilai Tugas    : ", tugas)
print("Nilai UTS      : ", uts)
print("Nilai UAS      : ", uas)
print("Nilai Akhir    : ", nilai_akhir)
print("Predikat       : ", predikat)

# %% [markdown]
# ```
# Masukkan Nama : Gilang
# Masukkan Nilai Tugas : 90
# Masukkan Nilai UTS : 90
# Masukkan Nilai UAS : 90
#
# ====== HASIL NILAI ======
# Nama           :  Gilang
# Nilai Tugas    :  90
# Nilai UTS      :  90
# Nilai UAS      :  90
# Nilai Akhir    :  90.0
# Predikat       :  A
# ```

# %% [markdown]
# **Penjelasan :** Program ini hanya program sederhana yang menginput dan menampilkan hasil nilai dan predikat.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang memiliki sintaks sederhana dan sesuai untuk mempelajari dasar pemrograman. Visual Studio Code dapat digunakan untuk menulis, menjalankan, dan mengembangkan program Python dengan berbagai fitur pendukung. Selain itu, GitHub dapat dimanfaatkan untuk menyimpan dan mengelola kode program secara daring melalui repository. Melalui praktikum ini, mahasiswa memperoleh pemahaman dasar mengenai penggunaan Python, VS Code, serta proses menghubungkan dan mengunggah proyek ke GitHub.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation. (2026). The Python Tutorial. Python Documentation. https://docs.python.org/3/tutorial/
#
# [2] Microsoft. (2026). Python in Visual Studio Code. Visual Studio Code Documentation. https://code.visualstudio.com/docs/languages/python
#
# [3] GitHub. (2026). About repositories. GitHub Docs. https://docs.github.com/en/repositories/creating-and-managing-repositories/about-repositories
#
# [4] GitHub. (2026). About remote repositories. GitHub Docs. https://docs.github.com/en/get-started/git-basics/about-remote-repositories
